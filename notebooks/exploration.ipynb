# %%
import sys
import os

# Add parent directory to path
sys.path.append(os.path.abspath(".."))

# %%
from models.neural_network import create_bagh_chal_model
import numpy as np

# %%
# Define action space size (number of possible moves)
action_space_size = 50  # Example, adjust based on game design

# Create the model
model = create_bagh_chal_model(action_space_size)

# Print the model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 3, 5, 5)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 3, 5, 128) │      5,888 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 3, 5, 128) │    147,584 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 3, 5, 128) │    147,584 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
# Test the model with dummy input
dummy_input = np.random.random((1, 3, 5, 5))  # Batch size = 1, 3 channels, 5x5 grid
policy_output, value_output = model.predict(dummy_input)

print("Policy Output Shape:", policy_output.shape)
print("Value Output:", value_output)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# Policy Output Shape: (1, 50)
# Value Output: [[0.]]
